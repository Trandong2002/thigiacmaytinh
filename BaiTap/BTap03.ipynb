# %%
# Import thư viện
from PIL import Image
from imgtools import*

# %%
# Đường dẫn ảnh 
my_path ='C:/Users/HP/Hinhanh/05.jpg'

# %%
# Đọc ảnh
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=308x164>

# %%
# Kích thước ban đầu
print(img.size)
# Out:
# (308, 164)

# %%
# Thay đổi kích thước ảnh
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
# Thay đổi kích thước
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x27>

# %%
dir = 'C:/Users/HP/Hinhanh'

# %%
image_path = dir + '/05.JPG'
print(image_path)
# Out:
# C:/Users/HP/Hinhanh/05.JPG

# %%
HPHinhanh = Image.open(image_path)

# %%
display(HPHinhanh)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=308x164>

# %%
print(" Định dạng ảnh: ", HPHinhanh.format)
# Out:
#  Định dạng ảnh:  JPEG

# %%
print("Kích cỡ ảnh: ", HPHinhanh.size)
# Out:
# Kích cỡ ảnh:  (308, 164)

# %%
new_HP_Hinhanh_path = dir + "/LangBac.JPG"
HPHinhanh.save(new_HP_Hinhanh_path)

# %%
HPHinhanh.close()
